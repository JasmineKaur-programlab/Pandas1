# %% [markdown]
# <a href="https://colab.research.google.com/github/JasmineKaur-programlab/Pandas1/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('pokemon.csv')

# %%
print(df)
# Out:
#                        abilities  against_bug  ...  generation  is_legendary
# 0    ['Overgrow', 'Chlorophyll']         1.00  ...           1             0
# 1    ['Overgrow', 'Chlorophyll']         1.00  ...           1             0
# 2    ['Overgrow', 'Chlorophyll']         1.00  ...           1             0
# 3       ['Blaze', 'Solar Power']         0.50  ...           1             0
# 4       ['Blaze', 'Solar Power']         0.50  ...           1             0
# ..                           ...          ...  ...         ...           ...
# 796              ['Beast Boost']         0.25  ...           7             1
# 797              ['Beast Boost']         1.00  ...           7             1
# 798              ['Beast Boost']         2.00  ...           7             1
# 799              ['Prism Armor']         2.00  ...           7             1
# 800               ['Soul-Heart']         0.25  ...           7             1
#
# [801 rows x 41 columns]

# %%
print(df.head(3))
# Out:
#                      abilities  against_bug  ...  generation  is_legendary
# 0  ['Overgrow', 'Chlorophyll']          1.0  ...           1             0
# 1  ['Overgrow', 'Chlorophyll']          1.0  ...           1             0
# 2  ['Overgrow', 'Chlorophyll']          1.0  ...           1             0
#
# [3 rows x 41 columns]

# %%
print(df.tail(3))
# Out:
#            abilities  against_bug  ...  generation  is_legendary
# 798  ['Beast Boost']         2.00  ...           7             1
# 799  ['Prism Armor']         2.00  ...           7             1
# 800   ['Soul-Heart']         0.25  ...           7             1
#
# [3 rows x 41 columns]

# %%
#df_xslx = pd.read_excel('pokemon_data.xlsx')
#print(df_xlsx.head(3))

# %%
#df = pd.read_csv('pokemon_data.txt')
#print(df)

# %%
#df = pd.read_csv('pokemon_data.txt',delimeter ='\t')
#print(df)

# %%
#read headers
print(df.columns)
# Out:
# Index(['abilities', 'against_bug', 'against_dark', 'against_dragon',
#        'against_electric', 'against_fairy', 'against_fight', 'against_fire',
#        'against_flying', 'against_ghost', 'against_grass', 'against_ground',
#        'against_ice', 'against_normal', 'against_poison', 'against_psychic',
#        'against_rock', 'against_steel', 'against_water', 'attack',
#        'base_egg_steps', 'base_happiness', 'base_total', 'capture_rate',
#        'classfication', 'defense', 'experience_growth', 'height_m', 'hp',
#        'japanese_name', 'name', 'percentage_male', 'pokedex_number',
#        'sp_attack', 'sp_defense', 'speed', 'type1', 'type2', 'weight_kg',
#        'generation', 'is_legendary'],
#       dtype='object')

# %%
#read_each column
print(df[['abilities','against_bug','against_dark']])
# Out:
#                        abilities  against_bug  against_dark
# 0    ['Overgrow', 'Chlorophyll']         1.00           1.0
# 1    ['Overgrow', 'Chlorophyll']         1.00           1.0
# 2    ['Overgrow', 'Chlorophyll']         1.00           1.0
# 3       ['Blaze', 'Solar Power']         0.50           1.0
# 4       ['Blaze', 'Solar Power']         0.50           1.0
# ..                           ...          ...           ...
# 796              ['Beast Boost']         0.25           1.0
# 797              ['Beast Boost']         1.00           1.0
# 798              ['Beast Boost']         2.00           0.5
# 799              ['Prism Armor']         2.00           2.0
# 800               ['Soul-Heart']         0.25           0.5
#
# [801 rows x 3 columns]

# %%
#read each row
print(df.head(4))
# Out:
#                      abilities  against_bug  ...  generation  is_legendary
# 0  ['Overgrow', 'Chlorophyll']          1.0  ...           1             0
# 1  ['Overgrow', 'Chlorophyll']          1.0  ...           1             0
# 2  ['Overgrow', 'Chlorophyll']          1.0  ...           1             0
# 3     ['Blaze', 'Solar Power']          0.5  ...           1             0
#
# [4 rows x 41 columns]

# %%
print(df.iloc[1])
# Out:
# abilities            ['Overgrow', 'Chlorophyll']
# against_bug                                    1
# against_dark                                   1
# against_dragon                                 1
# against_electric                             0.5
# against_fairy                                0.5
# against_fight                                0.5
# against_fire                                   2
# against_flying                                 2
# against_ghost                                  1
# against_grass                               0.25
# against_ground                                 1
# against_ice                                    2
# against_normal                                 1
# against_poison                                 1
# against_psychic                                2
# against_rock                                   1
# against_steel                                  1
# against_water                                0.5
# ...

# %%
#read 1 to 4 rows
print(df.iloc[1:4])
# Out:
#                      abilities  against_bug  ...  generation  is_legendary
# 1  ['Overgrow', 'Chlorophyll']          1.0  ...           1             0
# 2  ['Overgrow', 'Chlorophyll']          1.0  ...           1             0
# 3     ['Blaze', 'Solar Power']          0.5  ...           1             0
#
# [3 rows x 41 columns]

# %%
#read a specific location(R,C)
print(df.iloc[2,1])
# Out:
# 1.0

# %%
#read each row
for index,row in df.iterrows():
  print(index,row['against_bug'])
# Out:
# 0 1.0
# 1 1.0
# 2 1.0
# 3 0.5
# 4 0.5
# 5 0.25
# 6 1.0
# 7 1.0
# 8 1.0
# 9 1.0
# 10 1.0
# 11 0.5
# 12 0.5
# 13 0.5
# 14 0.5
# 15 0.5
# 16 0.5
# 17 0.5
# 18 1.0
# 19 1.0
# 20 0.5
# 21 0.5
# 22 0.5
# 23 0.5
# 24 1.0
# 25 1.0
# 26 1.0
# 27 1.0
# 28 0.5
# 29 0.5
# 30 0.5
# 31 0.5
# 32 0.5
# 33 0.5
# 34 0.5
# 35 0.5
# 36 0.5
# 37 0.5
# 38 0.5
# 39 0.5
# 40 0.25
# 41 0.25
# 42 1.0
# 43 1.0
# 44 1.0
# 45 2.0
# 46 2.0
# 47 0.5
# 48 0.5
# 49 1.0
# 50 1.0
# 51 1.0
# 52 1.0
# 53 1.0
# 54 1.0
# 55 0.5
# 56 0.5
# 57 0.5
# 58 0.5
# 59 1.0
# 60 1.0
# 61 0.5
# 62 2.0
# 63 2.0
# 64 2.0
# 65 0.5
# 66 0.5
# 67 0.5
# 68 1.0
# 69 1.0
# 70 1.0
# 71 0.5
# 72 0.5
# 73 1.0
# 74 1.0
# 75 1.0
# 76 0.5
# 77 0.5
# 78 2.0
# 79 2.0
# 80 0.5
# 81 0.5
# 82 0.5
# 83 0.5
# 84 0.5
# 85 1.0
# 86 1.0
# 87 0.5
# 88 0.5
# 89 1.0
# 90 1.0
# 91 0.25
# 92 0.25
# 93 0.25
# 94 1.0
# 95 2.0
# 96 2.0
# 97 1.0
# 98 1.0
# 99 1.0
# 100 1.0
# 101 4.0
# 102 4.0
# 103 1.0
# 104 1.0
# 105 0.5
# 106 0.5
# 107 1.0
# 108 0.5
# 109 0.5
# ...

# %%
#conditional statements
df.loc[df['against_bug']==0.5]
# Out:
#                            abilities  against_bug  ...  generation  is_legendary
# 3           ['Blaze', 'Solar Power']          0.5  ...           1             0
# 4           ['Blaze', 'Solar Power']          0.5  ...           1             0
# 11   ['Compoundeyes', 'Tinted Lens']          0.5  ...           1             0
# 12       ['Shield Dust', 'Run Away']          0.5  ...           1             0
# 13                     ['Shed Skin']          0.5  ...           1             0
# ..                               ...          ...  ...         ...           ...
# 784  ['Electric Surge', 'Telepathy']          0.5  ...           7             1
# 787     ['Misty Surge', 'Telepathy']          0.5  ...           7             1
# 792                  ['Beast Boost']          0.5  ...           7             1
# 793                  ['Beast Boost']          0.5  ...           7             1
# 794                  ['Beast Boost']          0.5  ...           7             1
#
# ...

# %%
df.describe() #std deviation
# Out:
#        against_bug  against_dark  ...  generation  is_legendary
# count   801.000000    801.000000  ...  801.000000    801.000000
# mean      0.996255      1.057116  ...    3.690387      0.087391
# std       0.597248      0.438142  ...    1.930420      0.282583
# min       0.250000      0.250000  ...    1.000000      0.000000
# 25%       0.500000      1.000000  ...    2.000000      0.000000
# 50%       1.000000      1.000000  ...    4.000000      0.000000
# 75%       1.000000      1.000000  ...    5.000000      0.000000
# max       4.000000      4.000000  ...    7.000000      1.000000
#
# [8 rows x 34 columns]

# %%
df
# Out:
#                        abilities  against_bug  ...  generation  is_legendary
# 0    ['Overgrow', 'Chlorophyll']         1.00  ...           1             0
# 1    ['Overgrow', 'Chlorophyll']         1.00  ...           1             0
# 2    ['Overgrow', 'Chlorophyll']         1.00  ...           1             0
# 3       ['Blaze', 'Solar Power']         0.50  ...           1             0
# 4       ['Blaze', 'Solar Power']         0.50  ...           1             0
# ..                           ...          ...  ...         ...           ...
# 796              ['Beast Boost']         0.25  ...           7             1
# 797              ['Beast Boost']         1.00  ...           7             1
# 798              ['Beast Boost']         2.00  ...           7             1
# 799              ['Prism Armor']         2.00  ...           7             1
# 800               ['Soul-Heart']         0.25  ...           7             1
#
# [801 rows x 41 columns]

# %%
df.sort_values('abilities',ascending =False)
# Out:
#                                           abilities  ...  is_legendary
# 560  ['Wonder Skin ', 'Magic Guard', 'Tinted Lens']  ...             0
# 291                                ['Wonder Guard']  ...             0
# 766                                    ['Wimp Out']  ...             0
# 323       ['White Smoke', 'Drought', 'Shell Armor']  ...             0
# 319         ['Water Veil', 'Oblivious', 'Pressure']  ...             0
# ..                                              ...  ...           ...
# 453    ['Anticipation', 'Dry Skin', 'Poison Touch']  ...             0
# 383                                    ['Air Lock']  ...             1
# 425        ['Aftermath', 'Unburden', 'Flare Boost']  ...             0
# 424        ['Aftermath', 'Unburden', 'Flare Boost']  ...             0
# 473        ['Adaptability', 'Download', 'Analytic']  ...             0
#
# [801 rows x 41 columns]

# %%
#sorting based on multiple 
df.sort_values(['abilities','classfication'],ascending = False)
#df.sort_values(['abilities','classfication'],ascending =[1,0])
# Out:
#                                           abilities  ...  is_legendary
# 560  ['Wonder Skin ', 'Magic Guard', 'Tinted Lens']  ...             0
# 291                                ['Wonder Guard']  ...             0
# 766                                    ['Wimp Out']  ...             0
# 323       ['White Smoke', 'Drought', 'Shell Armor']  ...             0
# 320         ['Water Veil', 'Oblivious', 'Pressure']  ...             0
# ..                                              ...  ...           ...
# 453    ['Anticipation', 'Dry Skin', 'Poison Touch']  ...             0
# 383                                    ['Air Lock']  ...             1
# 425        ['Aftermath', 'Unburden', 'Flare Boost']  ...             0
# 424        ['Aftermath', 'Unburden', 'Flare Boost']  ...             0
# 473        ['Adaptability', 'Download', 'Analytic']  ...             0
#
# [801 rows x 41 columns]

# %%
df.sort_values(['abilities','classfication'])
# Out:
#                                           abilities  ...  is_legendary
# 473        ['Adaptability', 'Download', 'Analytic']  ...             0
# 424        ['Aftermath', 'Unburden', 'Flare Boost']  ...             0
# 425        ['Aftermath', 'Unburden', 'Flare Boost']  ...             0
# 383                                    ['Air Lock']  ...             1
# 452    ['Anticipation', 'Dry Skin', 'Poison Touch']  ...             0
# ..                                              ...  ...           ...
# 320         ['Water Veil', 'Oblivious', 'Pressure']  ...             0
# 323       ['White Smoke', 'Drought', 'Shell Armor']  ...             0
# 766                                    ['Wimp Out']  ...             0
# 291                                ['Wonder Guard']  ...             0
# 560  ['Wonder Skin ', 'Magic Guard', 'Tinted Lens']  ...             0
#
# [801 rows x 41 columns]

# %% [markdown]
# ### Make changes to data

# %%
df.head()
# Out:
#                      abilities  against_bug  ...  generation  is_legendary
# 0  ['Overgrow', 'Chlorophyll']          1.0  ...           1             0
# 1  ['Overgrow', 'Chlorophyll']          1.0  ...           1             0
# 2  ['Overgrow', 'Chlorophyll']          1.0  ...           1             0
# 3     ['Blaze', 'Solar Power']          0.5  ...           1             0
# 4     ['Blaze', 'Solar Power']          0.5  ...           1             0
#
# [5 rows x 41 columns]

# %%
#add and create a total_category
df['Total'] = df['hp']+ df['attack']+ df['sp_attack'] + df['sp_defense'] + df['speed']

# %%
df.head(5)
# Out:
#                      abilities  against_bug  ...  is_legendary  Total
# 0  ['Overgrow', 'Chlorophyll']          1.0  ...             0    269
# 1  ['Overgrow', 'Chlorophyll']          1.0  ...             0    342
# 2  ['Overgrow', 'Chlorophyll']          1.0  ...             0    502
# 3     ['Blaze', 'Solar Power']          0.5  ...             0    266
# 4     ['Blaze', 'Solar Power']          0.5  ...             0    347
#
# [5 rows x 42 columns]

# %%
df.drop(columns=['Total'])
# Out:
#                        abilities  against_bug  ...  generation  is_legendary
# 0    ['Overgrow', 'Chlorophyll']         1.00  ...           1             0
# 1    ['Overgrow', 'Chlorophyll']         1.00  ...           1             0
# 2    ['Overgrow', 'Chlorophyll']         1.00  ...           1             0
# 3       ['Blaze', 'Solar Power']         0.50  ...           1             0
# 4       ['Blaze', 'Solar Power']         0.50  ...           1             0
# ..                           ...          ...  ...         ...           ...
# 796              ['Beast Boost']         0.25  ...           7             1
# 797              ['Beast Boost']         1.00  ...           7             1
# 798              ['Beast Boost']         2.00  ...           7             1
# 799              ['Prism Armor']         2.00  ...           7             1
# 800               ['Soul-Heart']         0.25  ...           7             1
#
# [801 rows x 41 columns]

# %%
df['Total'] = df.iloc[:, 4:10].sum(axis=1)
df.head(5)
# Out:
#                      abilities  against_bug  ...  is_legendary  Total
# 0  ['Overgrow', 'Chlorophyll']          1.0  ...             0    6.5
# 1  ['Overgrow', 'Chlorophyll']          1.0  ...             0    6.5
# 2  ['Overgrow', 'Chlorophyll']          1.0  ...             0    6.5
# 3     ['Blaze', 'Solar Power']          0.5  ...             0    5.0
# 4     ['Blaze', 'Solar Power']          0.5  ...             0    5.0
#
# [5 rows x 42 columns]

# %%
cols = list(df.columns.values)
#df = df[cols[0:4]+[cols[-1]+cols[4:12]]

# %%
df.to_csv('modified.csv')
#df.to_csv('modified.csv',index =False)

# %%
#Filtering the data
df.loc[(df['type1'] == 'grass') & (df['type2'] == 'poison')]
# Out:
#                                           abilities  ...  Total
# 0                       ['Overgrow', 'Chlorophyll']  ...    6.5
# 1                       ['Overgrow', 'Chlorophyll']  ...    6.5
# 2                       ['Overgrow', 'Chlorophyll']  ...    6.5
# 42                      ['Chlorophyll', 'Run Away']  ...    6.5
# 43                        ['Chlorophyll', 'Stench']  ...    6.5
# 44                  ['Chlorophyll', 'Effect Spore']  ...    6.5
# 68                      ['Chlorophyll', 'Gluttony']  ...    6.5
# 69                      ['Chlorophyll', 'Gluttony']  ...    6.5
# 70                      ['Chlorophyll', 'Gluttony']  ...    6.5
# 314  ['Natural Cure', 'Poison Point', 'Leaf Guard']  ...    6.5
# 405  ['Natural Cure', 'Poison Point', 'Leaf Guard']  ...    6.5
# 406  ['Natural Cure', 'Poison Point', 'Technician']  ...    6.5
# 589                 ['Effect Spore', 'Regenerator']  ...    6.5
# 590                 ['Effect Spore', 'Regenerator']  ...    6.5
#
# ...
